# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import numpy as np
import PIL
from scipy.ndimage import gaussian_filter

from pathlib import Path
import sys
sys.path.append(str(Path(__session__).parent.parent))

# %%
from utils import *
from detect import *
from scipy.ndimage import distance_transform_edt
from skimage.morphology import medial_axis, skeletonize
import matplotlib.pyplot as plt
import math
import itertools

# %%
db = SalamandraDB(load_images=True)

# %%
salamandras = db.content
salamandra = salamandras['0']

# %%
mask = pad_mask(salamandras['0'].spots[19].detection.mask)
dist = mask_distance_field_from_point(mask)
p = mask_barycenter(mask)
direction_masks = [mask_arc_field_from_point(mask, p, a-40, a+40) for a in np.arange(0., 360., 10.)]
max_d = np.quantile(dist * mask, .99)
steps = np.linspace(0.1 * max_d, 2 * max_d, 12)
distance_masks = [distance_field_disk_coverage(dist, d) for d in steps]
d = np.array([[mask_proportion(dirmask * dstmask, mask) for dirmask in direction_masks] for dstmask in distance_masks])

# %%
img = mask
PIL.Image.fromarray((255 * img).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=L size=66x66>

# %%
d0 = mask_descriptor(salamandras['0'].spots[20].detection.mask)
np.argmin([descriptor_rotation_and_score(d0, mask_descriptor(spot.detection.mask)) for spot in salamandras['1'].spots])
# Out:
# 16

# %%
a0 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['0'].spots]
n0 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
aa0 = [np.concat([a] + [0.5 * a0[nidx] for nidx in n0[idx]]) for idx, a in enumerate(a0)]
a1 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['1'].spots]
n1 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
aa1 = [np.concat([a] + [0.5 * a1[nidx] for nidx in n1[idx]]) for idx, a in enumerate(a1)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[187], line 3
#       1 a0 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['0'].spots]
#       2 n0 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
# ----> 3 aa0 = [np.concat([a] + [0.5 * a0[nidx] for nidx in n0[idx]]) for idx, a in enumerate(a0)]
#       4 a1 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['1'].spots]
#       5 n1 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
#
# Cell In[187], line 3, in <listcomp>(.0)
#       1 a0 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['0'].spots]
#       2 n0 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
# ----> 3 aa0 = [np.concat([a] + [0.5 * a0[nidx] for nidx in n0[idx]]) for idx, a in enumerate(a0)]
#       4 a1 = [mask_barycenter_distance_quantile_area_ratio(spot.detection.mask, np.arange(0., 1., .1))[1] for spot in salamandras['1'].spots]
#       5 n1 = [np.array([v[0] for v in a[:2]]) for a in spot_nbhd(salamandras['0']).values()]
#
# File ~/anaconda3/envs/sam3/lib/python3.10/site-packages/numpy/__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'concat'

# %%
n = np.array([[np.linalg.norm(v0-v1) for v1 in aa1] for v0 in aa0])
idx = 9
np.argpartition(n[idx,:], 10)
# Out:
# array([ 3, 12,  7, 17, 14, 21,  1, 13, 22,  9, 10, 27,  8, 18,  4, 19,  2,
#         6, 26, 11,  5,  0, 28, 20, 15, 29, 24, 25, 16, 23])

# %%
PIL.Image.fromarray(overlay_spot_masks_with_numbers(np.array(salamandras['0'].body.detection.masked_image), salamandras['0'].spots))
# Out:
# <PIL.Image.Image image mode=RGBA size=1149x833>

# %%
PIL.Image.fromarray(overlay_spot_masks_with_numbers(np.array(salamandras['1'].body.detection.masked_image), salamandras['1'].spots))
# Out:
# <PIL.Image.Image image mode=RGBA size=504x665>

# %%
r = LOOKUP_RADIUS_FACTOR * scale
a_range = ANGLE_LOOKUP_RANGE
pp = trace_ridges(skel, skel_thin, r, a_range, R1_MUL * 4, A_RANGE_MUL * 2)
b = bezier_from_polyline(pp)

# %%
deep = dist * (dist >= scale)
deep_ridge = ridge_from_distance(deep)
r = LOOKUP_RADIUS_FACTOR * scale
a_range = ANGLE_LOOKUP_RANGE
pp = trace_ridges(ridge, deep_ridge, r, a_range, R1_MUL * 4, A_RANGE_MUL * 2)
b = bezier_from_polyline(pp)

# %%
PIL.Image.fromarray(draw_bezier(skel_thin, b))
# Out:
# <PIL.Image.Image image mode=RGBA size=3629x1202>

# %%
scale1 = np.quantile(dist[dist > 0], .7)
mid = dist * (dist >= scale1)
show_monochrome(ridge_from_distance(mid))
# Out:
# <PIL.Image.Image image mode=L size=504x665>
