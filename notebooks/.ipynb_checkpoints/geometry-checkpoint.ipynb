# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import numpy as np
import PIL
from scipy.ndimage import gaussian_filter

from pathlib import Path
import sys
sys.path.append(str(Path(__session__).parent.parent))

# %%
from utils import *
from detect import *

LOOKUP_RADIUS_FACTOR = .5
ANGLE_LOOKUP_RANGE = 20

# %%
db = SalamandraDB(load_images=True)

# %%
salamandra = db.content['0']
dist = mask_distance_transform(salamandra.body.detection.mask)
ridge = ridge_from_distance(dist)
scale = np.quantile(dist, .98)

# %%
deep = dist * (dist >= scale)
deep_ridge = ridge_from_distance(deep)
pp = trace_ridges(ridge, deep_ridge, LOOKUP_RADIUS_FACTOR * scale, ANGLE_LOOKUP_RANGE)
b = bezier_from_polyline(pp)

# %%
PIL.Image.fromarray(draw_bezier(ridge, b))
# Out:
# <PIL.Image.Image image mode=RGBA size=1149x833>
